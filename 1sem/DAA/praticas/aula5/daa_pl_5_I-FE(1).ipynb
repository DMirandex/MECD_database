# %% [markdown]
# # Dados e Aprendizagem Automática
# ### Part V

# %% [markdown]
# ## **I - Feature Engineering using Incidents Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# *Load the CSV - Incidents*

# %%
incid = ("incidents.csv")

# %% [markdown]
# **EDA**

# %%
incid.
# Out:
# Index(['city_name', 'magnitude_of_delay', 'delay_in_seconds', 'affected_roads',
#        'record_date', 'luminosity', 'avg_temperature', 'avg_atm_pressure',
#        'avg_humidity', 'avg_wind_speed', 'avg_precipitation', 'avg_rain',
#        'incidents'],
#       dtype='object')

# %%
incid.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city_name           5000 non-null   object
#  1   magnitude_of_delay  5000 non-null   object
#  2   delay_in_seconds    5000 non-null   int64
#  3   affected_roads      4915 non-null   object
#  4   record_date         5000 non-null   object
#  5   luminosity          5000 non-null   object
#  6   avg_temperature     5000 non-null   float64
#  7   avg_atm_pressure    5000 non-null   float64
#  8   avg_humidity        5000 non-null   float64
#  9   avg_wind_speed      5000 non-null   float64
#  10  avg_precipitation   5000 non-null   float64
#  11  avg_rain            5000 non-null   object
#  12  incidents           2972 non-null   object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 507.9+ KB

# %%
incid.
# Out:
#    city_name magnitude_of_delay  delay_in_seconds  \
# 0  Guimaraes          UNDEFINED                 0
# 1  Guimaraes          UNDEFINED               385
# 2  Guimaraes          UNDEFINED                69
# 3  Guimaraes              MAJOR              2297
# 4  Guimaraes          UNDEFINED                 0
#
#                                       affected_roads       record_date  \
# 0                                                  ,  2021-03-15 23:00
# 1                                              N101,  2021-12-25 18:00
# 2                                                  ,  2021-03-12 15:00
# 3  N101,R206,N105,N101,N101,N101,N101,N101,N101,N...  2021-09-29 09:00
# 4                          N101,N101,N101,N101,N101,  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva        NaN
# 1                0.0  Sem Chuva        NaN
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %% [markdown]
# **Dealing with missing values**

# %%
sns.heatmap(, yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
incid.isnull().
# Out:
# city_name                0
# magnitude_of_delay       0
# delay_in_seconds         0
# affected_roads          85
# record_date              0
# luminosity               0
# avg_temperature          0
# avg_atm_pressure         0
# avg_humidity             0
# avg_wind_speed           0
# avg_precipitation        0
# avg_rain                 0
# incidents             2028
# dtype: int64

# %%
incid['affected_roads']
# Out:
# 0                                                    ,
# 1                                                N101,
# 2                                                    ,
# 3    N101,R206,N105,N101,N101,N101,N101,N101,N101,N...
# 4                            N101,N101,N101,N101,N101,
# Name: affected_roads, dtype: object

# %%
incid[incid['affected_roads']
# Out:
#       city_name magnitude_of_delay  delay_in_seconds affected_roads  \
# 29    Guimaraes          UNDEFINED                64            NaN
# 76    Guimaraes          UNDEFINED               223            NaN
# 79    Guimaraes              MAJOR                80            NaN
# 91    Guimaraes          UNDEFINED                52            NaN
# 109   Guimaraes          UNDEFINED               139            NaN
# ...         ...                ...               ...            ...
# 4785  Guimaraes              MAJOR               298            NaN
# 4811  Guimaraes          UNDEFINED                96            NaN
# 4838  Guimaraes          UNDEFINED                36            NaN
# 4854  Guimaraes          UNDEFINED               233            NaN
# 4910  Guimaraes          UNDEFINED               324            NaN
#
#            record_date luminosity  avg_temperature  avg_atm_pressure  \
# 29    2021-01-22 09:00      LIGHT              8.0            1012.0
# 76    2021-01-29 08:00      LIGHT             11.0            1022.0
# 79    2021-12-24 21:00       DARK             11.0            1004.0
# 91    2021-03-02 13:00      LIGHT             13.0            1024.0
# 109   2021-12-27 13:00      LIGHT             15.0            1014.0
# ...                ...        ...              ...               ...
# 4785  2021-12-22 13:00      LIGHT             16.0            1015.0
# 4811  2021-03-11 15:00      LIGHT             13.0            1025.0
# 4838  2021-03-10 13:00      LIGHT             14.0            1025.0
# 4854  2021-01-29 20:00       DARK             11.0            1017.0
# 4910  2021-02-03 08:00      LIGHT             10.0            1012.0
#
#       avg_humidity  avg_wind_speed  avg_precipitation     avg_rain incidents
# 29            91.0             4.0                0.0    Sem Chuva    Medium
# 76            92.0             1.0                0.0    Sem Chuva      High
# 79            92.0             0.0                0.0    Sem Chuva       NaN
# 91            78.0             2.0                0.0    Sem Chuva       Low
# 109           88.0             5.0                0.0    Sem Chuva       NaN
# ...            ...             ...                ...          ...       ...
# 4785          71.0             3.0                0.0    Sem Chuva       NaN
# 4811          89.0             3.0                0.0  chuva fraca    Medium
# 4838          65.0             2.0                0.0    Sem Chuva       Low
# 4854          92.0             1.0                0.0    Sem Chuva      High
# 4910          90.0             2.0                0.0    Sem Chuva       Low
#
# [85 rows x 13 columns]

# %% [markdown]
# *Copy data to try different options of handling data*

# %%
incid1 = incid
incid2 = incid

# %% [markdown]
# **a) Drop**

# %%
incid1.drop(['affected_roads'], axis = 1
incid1.
# Out:
#    city_name magnitude_of_delay  delay_in_seconds       record_date  \
# 0  Guimaraes          UNDEFINED                 0  2021-03-15 23:00
# 1  Guimaraes          UNDEFINED               385  2021-12-25 18:00
# 2  Guimaraes          UNDEFINED                69  2021-03-12 15:00
# 3  Guimaraes              MAJOR              2297  2021-09-29 09:00
# 4  Guimaraes          UNDEFINED                 0  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva        NaN
# 1                0.0  Sem Chuva        NaN
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %% [markdown]
# **b) Fill with zero**

# %%
incid2.fillna(0
incid2.
# Out:
#    city_name magnitude_of_delay  delay_in_seconds  \
# 0  Guimaraes          UNDEFINED                 0
# 1  Guimaraes          UNDEFINED               385
# 2  Guimaraes          UNDEFINED                69
# 3  Guimaraes              MAJOR              2297
# 4  Guimaraes          UNDEFINED                 0
#
#                                       affected_roads       record_date  \
# 0                                                  ,  2021-03-15 23:00
# 1                                              N101,  2021-12-25 18:00
# 2                                                  ,  2021-03-12 15:00
# 3  N101,R206,N105,N101,N101,N101,N101,N101,N101,N...  2021-09-29 09:00
# 4                          N101,N101,N101,N101,N101,  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva          0
# 1                0.0  Sem Chuva          0
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %% [markdown]
# We will choose to *drop* the column since it does not bring added value to our goal

# %%
incid.drop(['affected_roads']

# %%
sns.heatmap(, yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
incid.
# Out:
# city_name                0
# magnitude_of_delay       0
# delay_in_seconds         0
# record_date              0
# luminosity               0
# avg_temperature          0
# avg_atm_pressure         0
# avg_humidity             0
# avg_wind_speed           0
# avg_precipitation        0
# avg_rain                 0
# incidents             2028
# dtype: int64

# %%
incid.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city_name           5000 non-null   object
#  1   magnitude_of_delay  5000 non-null   object
#  2   delay_in_seconds    5000 non-null   int64
#  3   record_date         5000 non-null   object
#  4   luminosity          5000 non-null   object
#  5   avg_temperature     5000 non-null   float64
#  6   avg_atm_pressure    5000 non-null   float64
#  7   avg_humidity        5000 non-null   float64
#  8   avg_wind_speed      5000 non-null   float64
#  9   avg_precipitation   5000 non-null   float64
#  10  avg_rain            5000 non-null   object
#  11  incidents           2972 non-null   object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 468.9+ KB

# %%
incid.
# Out:
#    city_name magnitude_of_delay  delay_in_seconds       record_date  \
# 0  Guimaraes          UNDEFINED                 0  2021-03-15 23:00
# 1  Guimaraes          UNDEFINED               385  2021-12-25 18:00
# 2  Guimaraes          UNDEFINED                69  2021-03-12 15:00
# 3  Guimaraes              MAJOR              2297  2021-09-29 09:00
# 4  Guimaraes          UNDEFINED                 0  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#    avg_precipitation   avg_rain  incidents
# 0                0.0  Sem Chuva        NaN
# 1                0.0  Sem Chuva        NaN
# 2                0.0  Sem Chuva        Low
# 3                0.0  Sem Chuva  Very_High
# 4                0.0  Sem Chuva       High

# %% [markdown]
# There are features that are of the type <em>object</em>: <em>city_name</em>, <em>magnitude_of_delay</em>, <em>record_date</em>, <em>luminosity</em>, <em>avg_rain</em> and <em>incidents</em>.

# %%
incid.
# Out:
# city_name                1
# magnitude_of_delay       3
# delay_in_seconds      1186
# record_date           5000
# luminosity               3
# avg_temperature         35
# avg_atm_pressure        36
# avg_humidity            83
# avg_wind_speed          11
# avg_precipitation        1
# avg_rain                 4
# incidents                4
# dtype: int64

# %% [markdown]
# The features <em>city_name</em> and <em>avg_precipitation</em> have only one value. We will start with <em>avg_precipitation</em>:

# %%
incid['avg_precipitation'].
# Out:
# 1

# %%
incid['avg_precipitation'].
# Out:
# count    5000.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: avg_precipitation, dtype: float64

# %% [markdown]
# Since 0 is the unique value of <em>avg_precipitation</em> and all entries have the same value, we will *drop* this feature

# %%
incid.drop(['avg_precipitation']
incid.
# Out:
#    city_name magnitude_of_delay  delay_in_seconds       record_date  \
# 0  Guimaraes          UNDEFINED                 0  2021-03-15 23:00
# 1  Guimaraes          UNDEFINED               385  2021-12-25 18:00
# 2  Guimaraes          UNDEFINED                69  2021-03-12 15:00
# 3  Guimaraes              MAJOR              2297  2021-09-29 09:00
# 4  Guimaraes          UNDEFINED                 0  2021-06-13 11:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 0       DARK             12.0            1013.0          70.0             1.0
# 1       DARK             12.0            1007.0          91.0             1.0
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
#
#     avg_rain  incidents
# 0  Sem Chuva        NaN
# 1  Sem Chuva        NaN
# 2  Sem Chuva        Low
# 3  Sem Chuva  Very_High
# 4  Sem Chuva       High

# %% [markdown]
# **Handling categoric data**

# %% [markdown]
# Feature <em>city_name</em>

# %%
incid['city_name'].
# Out:
# 0    Guimaraes
# 1    Guimaraes
# 2    Guimaraes
# 3    Guimaraes
# 4    Guimaraes
# Name: city_name, dtype: object

# %% [markdown]
# The unique value of <em>city_name</em> is <em>Guimarães</em> - we can *drop* this feature as well

# %%
incid.drop('city_name'
incid.dropna(

# %% [markdown]
# Feature <em>incidents</em>

# %%
print(incid['incidents'].
# Out:
# incidents
# High         1073
# Low           718
# Very_High     603
# Medium        578
# Name: count, dtype: int64

# %%
print(incid['incidents'].
# Out:
# 4

# %%
incidents_count = incid['incidents'].
sns.set(
sns.barplot(x=incidents_count.index
plt.title('Frequency Distribution of Incidents')
plt.('Number of Occurrences'
plt.('Incidents'
plt.

# %%
labels = incid['incidents'].astype('category').
counts = incid['incidents'].
sizes = [counts[var_cat] for var_cat ]
fig1, ax1 = plt.
ax1.pie(sizes, labels=labels, autopct='%1.1f%%'
ax1.axis(
plt.

# %% [markdown]
# We have several options of how to deal with *qualitative data*:

# %% [markdown]
# **a) Replace Values**

# %%
incid3=incid.
incid3.
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents
# 2        Low
# 3  Very_High
# 4       High
# 5     Medium
# 6        Low

# %% [markdown]
# Label association: None - 0, Low - 1, Medium - 2, High - 3, Very_High - 4

# %%
replace_map = {'incidents': {'None': 0, 'Low': 1, 'Medium': 2, 'High': 3}}

# %% [markdown]
# We can create a replacement map in another way:

# %%
labels = incid3['incidents'].astype('category').
replace_map_comp = {'incidents' : {k: v for k,v in zip(labels, list()))}}
print()
# Out:
# {'incidents': {'High': 1, 'Low': 2, 'Medium': 3, 'Very_High': 4}}

# %%
incid3.
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents
# 2        Low
# 3  Very_High
# 4       High
# 5     Medium
# 6        Low

# %%
incid3.replace(replace_map_comp,
incid3.
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_5648\3149972917.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   incid3.replace(replace_map_comp, inplace=True)
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents
# 2          2
# 3          4
# 4          1
# 5          3
# 6          2

# %%
print(incid3['incidents'])
# Out:
# int64

# %% [markdown]
# **b) Label encoding**

# %%
incid4=incid.
incid4.
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents
# 2        Low
# 3  Very_High
# 4       High
# 5     Medium
# 6        Low

# %%
print(incid4)
# Out:
# magnitude_of_delay     object
# delay_in_seconds        int64
# record_date            object
# luminosity             object
# avg_temperature       float64
# avg_atm_pressure      float64
# avg_humidity          float64
# avg_wind_speed        float64
# avg_rain               object
# incidents              object
# dtype: object

# %%
incid4['None'] = np.where(incid4['incidents'].str.contains('None'))
incid4.
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents  None
# 2        Low     0
# 3  Very_High     0
# 4       High     0
# 5     Medium     0
# 6        Low     0

# %% [markdown]
# With *LabelEncoder()*:

# %%
incid5=incid.
incid6=incid.

import LabelEncoder

le_make = 
incid5['incidents_code'] = le_make.fit_transform(incid6)

incid5.
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents  incidents_code
# 2        Low               1
# 3  Very_High               3
# 4       High               0
# 5     Medium               2
# 6        Low               1

# %% [markdown]
# **c) One-Hot encoding**

# %%
incid7 = incid.

import LabelBinarizer

lb = 
lb_results = lb.fit_transform(incid7['incidents'])
lb_results_df = pd.DataFrame(lb_results)

lb_results_df.
# Out:
#    High  Low  Medium  Very_High
# 0     0    1       0          0
# 1     0    0       0          1
# 2     1    0       0          0
# 3     0    0       1          0
# 4     0    1       0          0

# %%
result_df = pd.concat([incid7, lb_results_df])
result_df.
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED              69.0  2021-03-12 15:00      LIGHT
# 3              MAJOR            2297.0  2021-09-29 09:00      LIGHT
# 4          UNDEFINED               0.0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED               0.0  2021-12-07 23:00       DARK
# 6          UNDEFINED               0.0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents  High  Low  Medium  Very_High
# 2        Low   1.0  0.0     0.0        0.0
# 3  Very_High   0.0  0.0     1.0        0.0
# 4       High   0.0  1.0     0.0        0.0
# 5     Medium   1.0  0.0     0.0        0.0
# 6        Low   0.0  0.0     0.0        1.0

# %% [markdown]
# **d) Binary Encoding**

# %% [markdown]
# |   Level   | "Decimal encoding" | Binary encoding | One-Hot encoding |
# | :-------: | :----------------: | :-------------: | :--------------: |
# | None      |         0          |       000       |      000001      |
# | Low       |         1          |       001       |      000010      |
# | Medium    |         2          |       010       |      000100      |
# | High      |         3          |       011       |      001000      |
# | Very_High |         4          |       100       |      010000      |

# %% [markdown]
# For this technique it is needed to have the package <em>category_encoders</em> installed:
#
# <code>!pip install category_encoders</code>

# %%
incid8 = incid.

import category_encoders

bencoder = ce.BinaryEncoder()

df_binary.
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents_0  incidents_1  incidents_2
# 2            0            0            1
# 3            0            1            0
# 4            0            1            1
# 5            1            0            0
# 6            0            0            1

# %% [markdown]
# **e) Backward difference encoding**

# %%
incid9 = incid.

bde = ce.BackwardDifferenceEncoder()

df_bd.
# Out:
# C:\Users\filip\.conda\envs\pl3\Lib\site-packages\category_encoders\base_contrast_encoder.py:126: FutureWarning: Intercept column might not be added anymore in future releases (c.f. issue #370)
#   warnings.warn("Intercept column might not be added anymore in future releases (c.f. issue #370)",
# C:\Users\filip\.conda\envs\pl3\Lib\site-packages\category_encoders\base_contrast_encoder.py:126: FutureWarning: Intercept column might not be added anymore in future releases (c.f. issue #370)
#   warnings.warn("Intercept column might not be added anymore in future releases (c.f. issue #370)",
#    intercept magnitude_of_delay  delay_in_seconds       record_date  \
# 2          1          UNDEFINED                69  2021-03-12 15:00
# 3          1              MAJOR              2297  2021-09-29 09:00
# 4          1          UNDEFINED                 0  2021-06-13 11:00
# 5          1          UNDEFINED                 0  2021-12-07 23:00
# 6          1          UNDEFINED                 0  2021-12-05 05:00
#
#   luminosity  avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  \
# 2      LIGHT             14.0            1025.0          64.0             0.0
# 3      LIGHT             15.0            1028.0          75.0             1.0
# 4      LIGHT             27.0            1020.0          52.0             1.0
# 5       DARK              9.0            1015.0          94.0             0.0
# 6       DARK              8.0            1026.0          87.0             1.0
#
#     avg_rain  incidents_0  incidents_1  incidents_2
# 2  Sem Chuva        -0.75         -0.5        -0.25
# 3  Sem Chuva         0.25         -0.5        -0.25
# 4  Sem Chuva         0.25          0.5        -0.25
# 5  Sem Chuva         0.25          0.5         0.75
# 6  Sem Chuva        -0.75         -0.5        -0.25

# %% [markdown]
# **f) Factorize**

# %%
incid10 = incid.

# %%
incid10['incidents'] = pd.factorize(incid10['incidents'])
incid10.
# Out:
#   magnitude_of_delay  delay_in_seconds       record_date luminosity  \
# 2          UNDEFINED                69  2021-03-12 15:00      LIGHT
# 3              MAJOR              2297  2021-09-29 09:00      LIGHT
# 4          UNDEFINED                 0  2021-06-13 11:00      LIGHT
# 5          UNDEFINED                 0  2021-12-07 23:00       DARK
# 6          UNDEFINED                 0  2021-12-05 05:00       DARK
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed   avg_rain  \
# 2             14.0            1025.0          64.0             0.0  Sem Chuva
# 3             15.0            1028.0          75.0             1.0  Sem Chuva
# 4             27.0            1020.0          52.0             1.0  Sem Chuva
# 5              9.0            1015.0          94.0             0.0  Sem Chuva
# 6              8.0            1026.0          87.0             1.0  Sem Chuva
#
#    incidents
# 2          1
# 3          2
# 4          3
# 5          4
# 6          1

# %% [markdown]
# We will choose the *factorize* technique to keep going

# %%
incid['incidents'] = pd.factorize(incid['incidents'])

# %% [markdown]
# Regarding the features <em>magnitude_delay</em>, <em>luminosity</em> and <em>avg_rain</em>, we will *factorize* them for now

# %%
incid['magnitude_of_delay'] = pd.factorize(incid['magnitude_of_delay'])
incid['luminosity'] = pd.factorize(incid['luminosity'])
incid['avg_rain'] = pd.factorize(incid['avg_rain'])

incid.
# Out:
#    magnitude_of_delay  delay_in_seconds       record_date  luminosity  \
# 2                   1                69  2021-03-12 15:00           1
# 3                   2              2297  2021-09-29 09:00           1
# 4                   1                 0  2021-06-13 11:00           1
# 5                   1                 0  2021-12-07 23:00           2
# 6                   1                 0  2021-12-05 05:00           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 2             14.0            1025.0          64.0             0.0         1
# 3             15.0            1028.0          75.0             1.0         1
# 4             27.0            1020.0          52.0             1.0         1
# 5              9.0            1015.0          94.0             0.0         1
# 6              8.0            1026.0          87.0             1.0         1
#
#    incidents
# 2          1
# 3          2
# 4          3
# 5          4
# 6          1

# %% [markdown]
# **Handling dates**
#
# *Datetime Properties and Methods* (https://pandas.pydata.org/pandas-docs/version/0.23/api.html#datetimelike-properties)

# %%
incid11 = incid.

# %%
incid11['record_date'].
# Out:
# 2    2021-03-12 15:00
# 3    2021-09-29 09:00
# 4    2021-06-13 11:00
# 5    2021-12-07 23:00
# 6    2021-12-05 05:00
# Name: record_date, dtype: object

# %%
incid11['record_date'] = pd.to_datetime(incid11['record_date'])

# %%
assert incid11['record_date'].isnull().

# %%
incid11['record_date'].
# Out:
# 2   2021-03-12 15:00:00
# 3   2021-09-29 09:00:00
# 4   2021-06-13 11:00:00
# 5   2021-12-07 23:00:00
# 6   2021-12-05 05:00:00
# Name: record_date, dtype: datetime64[ns]

# %%
incid11['record_date_year'] = incid11['record_date'].
incid11['record_date_month'] = incid11['record_date'].
incid11['record_date_day'] = incid11['record_date'].
incid11['record_date_hour'] = incid11['record_date'].
incid11['record_date_minute'] = incid11['record_date'].

# %%
incid11.
# Out:
#    magnitude_of_delay  delay_in_seconds         record_date  luminosity  \
# 2                   1                69 2021-03-12 15:00:00           1
# 3                   2              2297 2021-09-29 09:00:00           1
# 4                   1                 0 2021-06-13 11:00:00           1
# 5                   1                 0 2021-12-07 23:00:00           2
# 6                   1                 0 2021-12-05 05:00:00           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 2             14.0            1025.0          64.0             0.0         1
# 3             15.0            1028.0          75.0             1.0         1
# 4             27.0            1020.0          52.0             1.0         1
# 5              9.0            1015.0          94.0             0.0         1
# 6              8.0            1026.0          87.0             1.0         1
#
#    incidents  record_date_year  record_date_month  record_date_day  \
# 2          1              2021                  3               12
# 3          2              2021                  9               29
# 4          3              2021                  6               13
# 5          4              2021                 12                7
# 6          1              2021                 12                5
#
#    record_date_hour  record_date_minute
# 2                15                   0
# 3                 9                   0
# 4                11                   0
# 5                23                   0
# 6                 5                   0

# %%
incid11.
# Out:
# magnitude_of_delay       3
# delay_in_seconds      1167
# record_date           2972
# luminosity               3
# avg_temperature         34
# avg_atm_pressure        34
# avg_humidity            80
# avg_wind_speed          11
# avg_rain                 4
# incidents                4
# record_date_year         1
# record_date_month       11
# record_date_day         31
# record_date_hour        24
# record_date_minute       1
# dtype: int64

# %% [markdown]
# Since the year and the minute have only one value, we will *drop* it

# %%
incid11.drop('record_date_year',axis=1)
incid11.drop('record_date_minute',axis=1)
incid11.drop('record_date',inplace=True)
incid11.dropna()

# %%
incid11.
# Out:
#    magnitude_of_delay  delay_in_seconds  luminosity  avg_temperature  \
# 2                   1                69           1             14.0
# 3                   2              2297           1             15.0
# 4                   1                 0           1             27.0
# 5                   1                 0           2              9.0
# 6                   1                 0           2              8.0
#
#    avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  incidents  \
# 2            1025.0          64.0             0.0         1          1
# 3            1028.0          75.0             1.0         1          2
# 4            1020.0          52.0             1.0         1          3
# 5            1015.0          94.0             0.0         1          4
# 6            1026.0          87.0             1.0         1          1
#
#    record_date_month  record_date_day  record_date_hour
# 2                  3               12                15
# 3                  9               29                 9
# 4                  6               13                11
# 5                 12                7                23
# 6                 12                5                 5

# %%
incid12 = incid.

# %%
incid12['record_date'] = pd.to_datetime()
incid12.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2972 entries, 2 to 4995
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   magnitude_of_delay  2972 non-null   int64
#  1   delay_in_seconds    2972 non-null   int64
#  2   record_date         2972 non-null   datetime64[ns]
#  3   luminosity          2972 non-null   int64
#  4   avg_temperature     2972 non-null   float64
#  5   avg_atm_pressure    2972 non-null   float64
#  6   avg_humidity        2972 non-null   float64
#  7   avg_wind_speed      2972 non-null   float64
#  8   avg_rain            2972 non-null   int64
#  9   incidents           2972 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(5)
# memory usage: 319.9 KB

# %%
incid12['record_date'].
# Out:
# 2   2021-03-12 15:00:00
# 3   2021-09-29 09:00:00
# 4   2021-06-13 11:00:00
# 5   2021-12-07 23:00:00
# 6   2021-12-05 05:00:00
# Name: record_date, dtype: datetime64[ns]

# %%
today = datetime.
today
# Out:
# datetime.datetime(2024, 10, 14, 17, 50, 16, 977144)

# %%
today - incid12[]
# Out:
# 2      1312 days 02:50:16.977144
# 3      1111 days 08:50:16.977144
# 4      1219 days 06:50:16.977144
# 5      1041 days 18:50:16.977144
# 6      1044 days 12:50:16.977144
#                   ...
# 4991   1115 days 23:50:16.977144
# 4992   1254 days 06:50:16.977144
# 4993   1209 days 01:50:16.977144
# 4994   1208 days 19:50:16.977144
# 4995   1280 days 17:50:16.977144
# Name: record_date, Length: 2972, dtype: timedelta64[ns]

# %%
(today - incid12['record_date'])
# Out:
# 2       1312
# 3       1111
# 4       1219
# 5       1041
# 6       1044
#         ...
# 4991    1115
# 4992    1254
# 4993    1209
# 4994    1208
# 4995    1280
# Name: record_date, Length: 2972, dtype: int64

# %%
incid12['day'] = incid12['record_date']
incid12['month'] = incid12['record_date']
incid12['hour'] = incid12['record_date']
incid12['time'] = incid12['record_date']
incid12.
# Out:
#    magnitude_of_delay  delay_in_seconds         record_date  luminosity  \
# 2                   1                69 2021-03-12 15:00:00           1
# 3                   2              2297 2021-09-29 09:00:00           1
# 4                   1                 0 2021-06-13 11:00:00           1
# 5                   1                 0 2021-12-07 23:00:00           2
# 6                   1                 0 2021-12-05 05:00:00           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 2             14.0            1025.0          64.0             0.0         1
# 3             15.0            1028.0          75.0             1.0         1
# 4             27.0            1020.0          52.0             1.0         1
# 5              9.0            1015.0          94.0             0.0         1
# 6              8.0            1026.0          87.0             1.0         1
#
#    incidents  day  month  hour      time
# 2          1   12      3    15  15:00:00
# 3          2   29      9     9  09:00:00
# 4          3   13      6    11  11:00:00
# 5          4    7     12    23  23:00:00
# 6          1    5     12     5  05:00:00

# %%
incid['record_date'] = pd.to_datetime(format = '%Y-%m-%d %H:%M', errors='coerce')

# %%
incid.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2972 entries, 2 to 4995
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   magnitude_of_delay  2972 non-null   int64
#  1   delay_in_seconds    2972 non-null   int64
#  2   record_date         2972 non-null   datetime64[ns]
#  3   luminosity          2972 non-null   int64
#  4   avg_temperature     2972 non-null   float64
#  5   avg_atm_pressure    2972 non-null   float64
#  6   avg_humidity        2972 non-null   float64
#  7   avg_wind_speed      2972 non-null   float64
#  8   avg_rain            2972 non-null   int64
#  9   incidents           2972 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(5)
# memory usage: 319.9 KB

# %%
incid.
# Out:
#    magnitude_of_delay  delay_in_seconds         record_date  luminosity  \
# 2                   1                69 2021-03-12 15:00:00           1
# 3                   2              2297 2021-09-29 09:00:00           1
# 4                   1                 0 2021-06-13 11:00:00           1
# 5                   1                 0 2021-12-07 23:00:00           2
# 6                   1                 0 2021-12-05 05:00:00           2
#
#    avg_temperature  avg_atm_pressure  avg_humidity  avg_wind_speed  avg_rain  \
# 2             14.0            1025.0          64.0             0.0         1
# 3             15.0            1028.0          75.0             1.0         1
# 4             27.0            1020.0          52.0             1.0         1
# 5              9.0            1015.0          94.0             0.0         1
# 6              8.0            1026.0          87.0             1.0         1
#
#    incidents
# 2          1
# 3          2
# 4          3
# 5          4
# 6          1
